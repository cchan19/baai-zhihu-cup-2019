# %%
import pandas as pd
import numpy as np
import pickle
import gc
import os
import time
import copy
import multiprocessing as mp
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_auc_score, log_loss
from tqdm import tqdm
from scipy import sparse, spatial
import warnings
warnings.filterwarnings('ignore')
tqdm.pandas()

# %%
import os
import tensorflow as tf

os.environ['CUDA_VISIBLE_DEVICES'] = "0"
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

from keras.models import Sequential, Model
from keras.layers import Input, Dense, CuDNNLSTM, Bidirectional, Embedding, CuDNNGRU, Conv1D, MaxPooling1D
from keras.layers import Flatten, PReLU, Dropout, BatchNormalization, SpatialDropout1D, concatenate
from keras import initializers, regularizers, constraints, optimizers, layers
from keras.preprocessing.sequence import pad_sequences
from keras.utils import Sequence
from keras.callbacks import Callback
from keras import backend as K
from keras.engine.topology import Layer 
# from keras.utils.training_utils import multi_gpu_model
# Out:
# Using TensorFlow backend.

# %%
tic = time.time()
DATA_PATH = '../pkl/'
SAVE_PATH = './feats/'
WEIGHT_PATH = './weights/'
if not os.path.exists(SAVE_PATH):
    print('create dir: %s' % SAVE_PATH)
    os.mkdir(SAVE_PATH)
if not os.path.exists(WEIGHT_PATH):
    print('create dir: %s' % WEIGHT_PATH)
    os.mkdir(WEIGHT_PATH)

print('user_topic_dnn_enc_B...')
# Out:
# user_topic_dnn_enc_B...

# %%
data = pd.read_pickle(os.path.join(DATA_PATH, 'invite_data.pkl'))
user_info = pd.read_pickle(os.path.join(DATA_PATH, 'user_info.pkl'))
topic = pd.read_pickle(os.path.join(DATA_PATH, 'topic.pkl'))
len_train = (~data['label'].isnull()).sum()
print(len_train)
# Out:
# 9489162

# %%
data.head()
# Out:
#    iday  ihour  itime  label         qid         uid
# 0  3865     22  92782    0.0  2166419046   401693808
# 1  3844     11  92267    0.0  1550017551  3392373099
# 2  3862     15  92703    0.0   604029601  2317670257
# 3  3849     11  92387    0.0  2350061229  1618461867
# 4  3867      4  92812    0.0  2443223942  3544409350

# %%
user_info['topic'] = user_info['topic_a'] + user_info['topic_ik']

# %%
data = data.merge(user_info[['uid', 'topic']], 'left', 'uid')
# data['topic'] = data['topic'].fillna('-1')
data.head()
# Out:
#    iday  ihour  itime  label         qid         uid  \
# 0  3865     22  92782    0.0  2166419046   401693808
# 1  3844     11  92267    0.0  1550017551  3392373099
# 2  3862     15  92703    0.0   604029601  2317670257
# 3  3849     11  92387    0.0  2350061229  1618461867
# 4  3867      4  92812    0.0  2443223942  3544409350
#
#                                                topic
# 0  [1727, 5310, 3402, 916, 1506, 26329, 7293, 180...
# 1  [42595, 3, 8520, 597, 6485, 6212, 25664, 148, ...
# 2  [610, 448, 61, 2801, 9019, 65, 233, 190, 55, 5...
# 3  [5, 33331, 2274, 31, 245, 516, 309, 1326, 119,...
# 4  [0, 4876, 2467, 245, 68, 556, 42, 8, 825, 227,...

# %%
max_len = data['topic'].apply(len).max()
print(max_len)
# Out:
# 110

# %%
np.random.seed(42)
def shuffle(l):
    np.random.shuffle(l)
    return l

data['topic'] = data['topic'].progress_apply(shuffle)
# Out:
# 100%|██████████| 10630845/10630845 [00:29<00:00, 365319.38it/s]

# %%
data.head()
# Out:
#    iday  ihour  itime  label         qid         uid  \
# 0  3865     22  92782    0.0  2166419046   401693808
# 1  3844     11  92267    0.0  1550017551  3392373099
# 2  3862     15  92703    0.0   604029601  2317670257
# 3  3849     11  92387    0.0  2350061229  1618461867
# 4  3867      4  92812    0.0  2443223942  3544409350
#
#                                                topic
# 0  [16, 1734, 18098, 2794, 14572, 38, 3020, 28, 1...
# 1  [25664, 2959, 394, 460, 2294, 910, 112, 8520, ...
# 2  [316, 207, 2801, 8943, 148, 553, 233, 11078, 9...
# 3  [1074, 320, 124, 1918, 119, 31, 820, 1096, 177...
# 4  [825, 4876, 556, 0, 68, 637, 42, 2467, 245, 22...

# %%
topics = pad_sequences(data['topic'], maxlen=max_len)

# %%
topics.shape
# Out:
# (10630845, 110)

# %%
embed_weights = np.array([[0] * 64] + [list(v) for v in topic['vector'].values])

# %%
embed_weights.shape
# Out:
# (100001, 64)

# %%
class DataSequence(Sequence):
    
    def __init__(self, x, y, batch_size=128):
        self.x = x
        self.y = y
        self.batch_size = batch_size
         
    def __len__(self):
        return int(np.ceil(self.x.shape[0] / float(self.batch_size)))
    
    def __getitem__(self, idx):
        batch_idx = np.arange(idx * self.batch_size, min((idx + 1) * self.batch_size, self.x.shape[0]))
        batch_x = self.x[batch_idx]# .toarray() # sparse to dense
        batch_y = self.y[batch_idx]
        return batch_x, batch_y

# %%
class MetricsCallback(Callback):
    def __init__(self, x_trn, y_trn, x_val, y_val, batch_size=128, save_name='weight.h5'):
        self.trn_generator = DataSequence(x_trn, y_trn, BATCH_SIZE)
        self.val_generator = DataSequence(x_val, y_val, BATCH_SIZE)
        self.y_trn = y_trn
        self.y_val = y_val
        self.save_name = save_name
        self.best_score = 0.5

    def on_epoch_end(self, epoch, logs={}):
        # eval train
        y_pred = self.model.predict_generator(self.trn_generator, 
                                              max_queue_size=10, 
                                              workers=1, 
                                              use_multiprocessing=False, 
                                              verbose=0)
        roc = roc_auc_score(self.y_trn, y_pred)
        # eval valid
        y_pred_val = self.model.predict_generator(self.val_generator, 
                                              max_queue_size=10, 
                                              workers=1, 
                                              use_multiprocessing=False, 
                                              verbose=0)
        roc_val = roc_auc_score(self.y_val, y_pred_val)
        print('\rroc-auc: %s - roc-auc_val: %s' % (str(round(roc,4)),str(round(roc_val,4))),end=100*' '+'\n')
#         print(roc_val)
#         print(log_loss(self.y_val, y_pred_val)/len(y_pred_val))
        if roc_val > self.best_score:
            self.best_score = roc_val
            self.model.save_weights(os.path.join(WEIGHT_PATH, self.save_name))
        
        return

# %%
def Net(in_dim, hiddens=(256,256)):
    inp = Input(shape=(max_len,))
    x = Embedding(embed_weights.shape[0], embed_weights.shape[1], weights=[embed_weights], trainable=False)(inp)
    x = Dropout(0.2)(x)
    x = Flatten()(x)
    for hs in hiddens:
        x = Dense(hs)(x)
        x = BatchNormalization()(x)
        x = PReLU()(x)
        x = Dropout(0.2)(x)
    out = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=out)
    return model

# %%
train_x = topics[:len_train]
test_x = topics[len_train:]
train_y = data['label'].values[:len_train]

# %%
print(train_x.shape)
print(test_x.shape)
print(train_y.sum() / len(train_y))
# Out:
# (9489162, 110)
# (1141683, 110)
# 0.1773515933229931

# %%
BATCH_SIZE = 1024

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for i, (tr_idx, va_idx) in enumerate(kfold.split(train_x, train_y)):
    print('-'*100)
    print('Fold %d' % i)
    trn_x, trn_y = train_x[tr_idx], train_y[tr_idx]
    val_x, val_y = train_x[va_idx], train_y[va_idx]
    
    K.clear_session()
    model = Net(in_dim=train_x.shape[1], hiddens=(256,256,256))
    model.compile(loss='binary_crossentropy', optimizer='adam',)
    
    trn_generator = DataSequence(trn_x, trn_y, batch_size=BATCH_SIZE)
    val_generator = DataSequence(val_x, val_y, batch_size=BATCH_SIZE)
    
    history = model.fit_generator(generator=trn_generator, 
                        epochs=30, 
                        verbose=1, 
                        callbacks=[MetricsCallback(trn_x, trn_y, val_x, val_y, 
                                                   batch_size=BATCH_SIZE*4, 
                                                   save_name='user_topic_dnn_enc_B_weight_fold%d.h5' % i)], 
                        max_queue_size=100, 
                        workers=1, 
                        use_multiprocessing=False,)
    
    del trn_x, trn_y, val_x, val_y
    gc.collect()
# Out:
# ----------------------------------------------------------------------------------------------------
# Fold 0
# Epoch 1/30
# 7414/7414 [==============================] - 77s 10ms/step - loss: 0.4642
# roc-auc: 0.6194 - roc-auc_val: 0.6028
# Epoch 2/30
# 7414/7414 [==============================] - 78s 11ms/step - loss: 0.4548
# roc-auc: 0.6495 - roc-auc_val: 0.6204
# Epoch 3/30
# 7414/7414 [==============================] - 76s 10ms/step - loss: 0.4492
# roc-auc: 0.6681 - roc-auc_val: 0.6293
# Epoch 4/30
# 7414/7414 [==============================] - 76s 10ms/step - loss: 0.4457
# roc-auc: 0.6776 - roc-auc_val: 0.6333
# Epoch 5/30
# 7414/7414 [==============================] - 76s 10ms/step - loss: 0.4433
# roc-auc: 0.6848 - roc-auc_val: 0.6362
# Epoch 6/30
# 7414/7414 [==============================] - 164s 22ms/step - loss: 0.4414
# roc-auc: 0.6919 - roc-auc_val: 0.6377
# Epoch 7/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4398
# roc-auc: 0.6975 - roc-auc_val: 0.6402
# Epoch 8/30
# 7414/7414 [==============================] - 113s 15ms/step - loss: 0.4387
# roc-auc: 0.6993 - roc-auc_val: 0.6407
# Epoch 9/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4375
# roc-auc: 0.7032 - roc-auc_val: 0.6416
# Epoch 10/30
# 7414/7414 [==============================] - 112s 15ms/step - loss: 0.4366
# roc-auc: 0.7066 - roc-auc_val: 0.6421
# Epoch 11/30
# 7414/7414 [==============================] - 78s 11ms/step - loss: 0.4357
# roc-auc: 0.7091 - roc-auc_val: 0.6433
# Epoch 12/30
# 7414/7414 [==============================] - 78s 10ms/step - loss: 0.4349
# roc-auc: 0.7086 - roc-auc_val: 0.6439
# Epoch 13/30
# 7414/7414 [==============================] - 78s 10ms/step - loss: 0.4342
# roc-auc: 0.7119 - roc-auc_val: 0.6441
# Epoch 14/30
# 7414/7414 [==============================] - 143s 19ms/step - loss: 0.4336
# roc-auc: 0.7128 - roc-auc_val: 0.644
# Epoch 15/30
# 7414/7414 [==============================] - 155s 21ms/step - loss: 0.4331
# roc-auc: 0.7148 - roc-auc_val: 0.6442
# Epoch 16/30
# 7414/7414 [==============================] - 154s 21ms/step - loss: 0.4325
# roc-auc: 0.7181 - roc-auc_val: 0.6447
# Epoch 17/30
# 7414/7414 [==============================] - 160s 22ms/step - loss: 0.4320
# roc-auc: 0.7184 - roc-auc_val: 0.6457
# Epoch 18/30
# 7414/7414 [==============================] - 157s 21ms/step - loss: 0.4314
# roc-auc: 0.7185 - roc-auc_val: 0.6456
# Epoch 19/30
# 7414/7414 [==============================] - 161s 22ms/step - loss: 0.4310
# roc-auc: 0.7212 - roc-auc_val: 0.6446
# Epoch 20/30
# 7414/7414 [==============================] - 156s 21ms/step - loss: 0.4307
# roc-auc: 0.7216 - roc-auc_val: 0.6455
# Epoch 21/30
# 7414/7414 [==============================] - 78s 11ms/step - loss: 0.4304
# roc-auc: 0.7227 - roc-auc_val: 0.646
# Epoch 22/30
# 7414/7414 [==============================] - 81s 11ms/step - loss: 0.4299
# roc-auc: 0.7234 - roc-auc_val: 0.6461
# Epoch 23/30
# 7414/7414 [==============================] - 77s 10ms/step - loss: 0.4295
# roc-auc: 0.7238 - roc-auc_val: 0.6458
# Epoch 24/30
# 7414/7414 [==============================] - 77s 10ms/step - loss: 0.4292
# roc-auc: 0.7257 - roc-auc_val: 0.6463
# Epoch 25/30
# 7414/7414 [==============================] - 77s 10ms/step - loss: 0.4289
# roc-auc: 0.7262 - roc-auc_val: 0.6462
# Epoch 26/30
# 7414/7414 [==============================] - 77s 10ms/step - loss: 0.4286
# roc-auc: 0.7265 - roc-auc_val: 0.6465
# Epoch 27/30
# 7414/7414 [==============================] - 77s 10ms/step - loss: 0.4283
# roc-auc: 0.727 - roc-auc_val: 0.6459
# Epoch 28/30
# 7414/7414 [==============================] - 77s 10ms/step - loss: 0.4280
# roc-auc: 0.7274 - roc-auc_val: 0.6464
# Epoch 29/30
# 7414/7414 [==============================] - 75s 10ms/step - loss: 0.4277
# roc-auc: 0.7299 - roc-auc_val: 0.6469
# Epoch 30/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4275
# roc-auc: 0.7279 - roc-auc_val: 0.6472
# ----------------------------------------------------------------------------------------------------
# Fold 1
# Epoch 1/30
# 7414/7414 [==============================] - 74s 10ms/step - loss: 0.4638
# roc-auc: 0.6203 - roc-auc_val: 0.602
# Epoch 2/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4549
# roc-auc: 0.6486 - roc-auc_val: 0.6198
# Epoch 3/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4494
# roc-auc: 0.6685 - roc-auc_val: 0.629
# Epoch 4/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4459
# roc-auc: 0.6784 - roc-auc_val: 0.6335
# Epoch 5/30
# 7414/7414 [==============================] - 72s 10ms/step - loss: 0.4433
# roc-auc: 0.6875 - roc-auc_val: 0.6366
# Epoch 6/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4415
# roc-auc: 0.6916 - roc-auc_val: 0.6384
# Epoch 7/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4399
# roc-auc: 0.6968 - roc-auc_val: 0.6401
# Epoch 8/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4387
# roc-auc: 0.7017 - roc-auc_val: 0.6415
# Epoch 9/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4376
# roc-auc: 0.7042 - roc-auc_val: 0.642
# Epoch 10/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4367
# roc-auc: 0.707 - roc-auc_val: 0.6427
# Epoch 11/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4358
# roc-auc: 0.7091 - roc-auc_val: 0.643
# Epoch 12/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4351
# roc-auc: 0.7107 - roc-auc_val: 0.6438
# Epoch 13/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4344
# roc-auc: 0.7132 - roc-auc_val: 0.6439
# Epoch 14/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4338
# roc-auc: 0.7145 - roc-auc_val: 0.6438
# Epoch 15/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4332
# roc-auc: 0.7161 - roc-auc_val: 0.6446
# Epoch 16/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4327
# roc-auc: 0.717 - roc-auc_val: 0.645
# Epoch 17/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4320
# roc-auc: 0.719 - roc-auc_val: 0.6447
# Epoch 18/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4317
# roc-auc: 0.7206 - roc-auc_val: 0.644
# Epoch 19/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4312
# roc-auc: 0.7211 - roc-auc_val: 0.6447
# Epoch 20/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4308
# roc-auc: 0.7217 - roc-auc_val: 0.6447
# Epoch 21/30
# 7414/7414 [==============================] - 68s 9ms/step - loss: 0.4304
# roc-auc: 0.7231 - roc-auc_val: 0.6452
# Epoch 22/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4300
# roc-auc: 0.7227 - roc-auc_val: 0.6457
# Epoch 23/30
# 7414/7414 [==============================] - 68s 9ms/step - loss: 0.4296
# roc-auc: 0.7253 - roc-auc_val: 0.6464
# Epoch 24/30
# 7414/7414 [==============================] - 68s 9ms/step - loss: 0.4293
# roc-auc: 0.7249 - roc-auc_val: 0.6459
# Epoch 25/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4290
# roc-auc: 0.726 - roc-auc_val: 0.6461
# Epoch 26/30
# 7414/7414 [==============================] - 67s 9ms/step - loss: 0.4287
# roc-auc: 0.7262 - roc-auc_val: 0.6465
# Epoch 27/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4285
# roc-auc: 0.727 - roc-auc_val: 0.6464
# Epoch 28/30
# 7414/7414 [==============================] - 67s 9ms/step - loss: 0.4283
# roc-auc: 0.7284 - roc-auc_val: 0.6462
# Epoch 29/30
# 7414/7414 [==============================] - 67s 9ms/step - loss: 0.4279
# roc-auc: 0.7285 - roc-auc_val: 0.6463
# Epoch 30/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4276
# roc-auc: 0.7296 - roc-auc_val: 0.6464
# ----------------------------------------------------------------------------------------------------
# Fold 2
# Epoch 1/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4639
# roc-auc: 0.6181 - roc-auc_val: 0.6012
# Epoch 2/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4549
# roc-auc: 0.651 - roc-auc_val: 0.6216
# Epoch 3/30
# 7414/7414 [==============================] - 68s 9ms/step - loss: 0.4493
# roc-auc: 0.6671 - roc-auc_val: 0.6289
# Epoch 4/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4459
# roc-auc: 0.6777 - roc-auc_val: 0.6339
# Epoch 5/30
# 7414/7414 [==============================] - 67s 9ms/step - loss: 0.4434
# roc-auc: 0.6861 - roc-auc_val: 0.6368
# Epoch 6/30
# 7414/7414 [==============================] - 73s 10ms/step - loss: 0.4415
# roc-auc: 0.6917 - roc-auc_val: 0.6393
# Epoch 7/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4400
# roc-auc: 0.6969 - roc-auc_val: 0.64
# Epoch 8/30
# 7414/7414 [==============================] - 68s 9ms/step - loss: 0.4388
# roc-auc: 0.6999 - roc-auc_val: 0.6413
# Epoch 9/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4377
# roc-auc: 0.7054 - roc-auc_val: 0.6419
# Epoch 10/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4367
# roc-auc: 0.7063 - roc-auc_val: 0.6422
# Epoch 11/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4359
# roc-auc: 0.7081 - roc-auc_val: 0.6434
# Epoch 12/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4351
# roc-auc: 0.7112 - roc-auc_val: 0.644
# Epoch 13/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4343
# roc-auc: 0.7124 - roc-auc_val: 0.6445
# Epoch 14/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4337
# roc-auc: 0.7138 - roc-auc_val: 0.6446
# Epoch 15/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4331
# roc-auc: 0.7157 - roc-auc_val: 0.6453
# Epoch 16/30
# 7414/7414 [==============================] - 67s 9ms/step - loss: 0.4326
# roc-auc: 0.715 - roc-auc_val: 0.6456
# Epoch 17/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4321
# roc-auc: 0.7182 - roc-auc_val: 0.6452
# Epoch 18/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4316
# roc-auc: 0.7199 - roc-auc_val: 0.6457
# Epoch 19/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4312
# roc-auc: 0.7198 - roc-auc_val: 0.6462
# Epoch 20/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4307
# roc-auc: 0.7221 - roc-auc_val: 0.6457
# Epoch 21/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4303
# roc-auc: 0.7223 - roc-auc_val: 0.6456
# Epoch 22/30
# 7414/7414 [==============================] - 66s 9ms/step - loss: 0.4300
# roc-auc: 0.7235 - roc-auc_val: 0.6462
# Epoch 23/30
# 7414/7414 [==============================] - 67s 9ms/step - loss: 0.4296
# roc-auc: 0.7238 - roc-auc_val: 0.6459
# Epoch 24/30
# 7414/7414 [==============================] - 70s 10ms/step - loss: 0.4292
# roc-auc: 0.7246 - roc-auc_val: 0.6464
# Epoch 25/30
# 7414/7414 [==============================] - 115s 16ms/step - loss: 0.4289
# roc-auc: 0.7271 - roc-auc_val: 0.6462
# Epoch 26/30
# 7414/7414 [==============================] - 122s 16ms/step - loss: 0.4286
# roc-auc: 0.7269 - roc-auc_val: 0.6467
# Epoch 27/30
# 7414/7414 [==============================] - 121s 16ms/step - loss: 0.4283
# roc-auc: 0.7269 - roc-auc_val: 0.6468
# Epoch 28/30
# 7414/7414 [==============================] - 128s 17ms/step - loss: 0.4281
# roc-auc: 0.7264 - roc-auc_val: 0.6466
# Epoch 29/30
# 7414/7414 [==============================] - 132s 18ms/step - loss: 0.4278
# roc-auc: 0.7279 - roc-auc_val: 0.6469
# Epoch 30/30
# 7414/7414 [==============================] - 129s 17ms/step - loss: 0.4275
# roc-auc: 0.7294 - roc-auc_val: 0.6474
# ----------------------------------------------------------------------------------------------------
# Fold 3
# Epoch 1/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4644
# roc-auc: 0.6198 - roc-auc_val: 0.603
# Epoch 2/30
# 7414/7414 [==============================] - 127s 17ms/step - loss: 0.4547
# roc-auc: 0.6515 - roc-auc_val: 0.6215
# Epoch 3/30
# 7414/7414 [==============================] - 128s 17ms/step - loss: 0.4491
# roc-auc: 0.6692 - roc-auc_val: 0.6294
# Epoch 4/30
# 7414/7414 [==============================] - 130s 18ms/step - loss: 0.4457
# roc-auc: 0.6793 - roc-auc_val: 0.6342
# Epoch 5/30
# 7414/7414 [==============================] - 128s 17ms/step - loss: 0.4433
# roc-auc: 0.6857 - roc-auc_val: 0.6365
# Epoch 6/30
# 7414/7414 [==============================] - 128s 17ms/step - loss: 0.4414
# roc-auc: 0.6926 - roc-auc_val: 0.6381
# Epoch 7/30
# 7414/7414 [==============================] - 129s 17ms/step - loss: 0.4399
# roc-auc: 0.6959 - roc-auc_val: 0.6393
# Epoch 8/30
# 7414/7414 [==============================] - 112s 15ms/step - loss: 0.4386
# roc-auc: 0.7005 - roc-auc_val: 0.6409
# Epoch 9/30
# 7414/7414 [==============================] - 127s 17ms/step - loss: 0.4375
# roc-auc: 0.7033 - roc-auc_val: 0.6418
# Epoch 10/30
# 7414/7414 [==============================] - 130s 17ms/step - loss: 0.4365
# roc-auc: 0.7054 - roc-auc_val: 0.6427
# Epoch 11/30
# 7414/7414 [==============================] - 128s 17ms/step - loss: 0.4357
# roc-auc: 0.7077 - roc-auc_val: 0.6423
# Epoch 12/30
# 7414/7414 [==============================] - 128s 17ms/step - loss: 0.4349
# roc-auc: 0.7078 - roc-auc_val: 0.6431
# Epoch 13/30
# 7414/7414 [==============================] - 135s 18ms/step - loss: 0.4342
# roc-auc: 0.7112 - roc-auc_val: 0.6436
# Epoch 14/30
# 7414/7414 [==============================] - 132s 18ms/step - loss: 0.4336
# roc-auc: 0.7139 - roc-auc_val: 0.6449
# Epoch 15/30
# 7414/7414 [==============================] - 117s 16ms/step - loss: 0.4330
# roc-auc: 0.7154 - roc-auc_val: 0.6451
# Epoch 16/30
# 7414/7414 [==============================] - 135s 18ms/step - loss: 0.4324
# roc-auc: 0.7166 - roc-auc_val: 0.6449
# Epoch 17/30
# 7414/7414 [==============================] - 132s 18ms/step - loss: 0.4320
# roc-auc: 0.7173 - roc-auc_val: 0.6456
# Epoch 18/30
# 7414/7414 [==============================] - 134s 18ms/step - loss: 0.4314
# roc-auc: 0.7181 - roc-auc_val: 0.6456
# Epoch 19/30
# 7414/7414 [==============================] - 134s 18ms/step - loss: 0.4310
# roc-auc: 0.7212 - roc-auc_val: 0.6449
# Epoch 20/30
# 7414/7414 [==============================] - 134s 18ms/step - loss: 0.4306
# roc-auc: 0.7227 - roc-auc_val: 0.6457
# Epoch 21/30
# 7414/7414 [==============================] - 130s 18ms/step - loss: 0.4302
# roc-auc: 0.7225 - roc-auc_val: 0.6452
# Epoch 22/30
# 7414/7414 [==============================] - 134s 18ms/step - loss: 0.4298
# roc-auc: 0.7235 - roc-auc_val: 0.6458
# Epoch 23/30
# 7414/7414 [==============================] - 133s 18ms/step - loss: 0.4294
# roc-auc: 0.723 - roc-auc_val: 0.6462
# Epoch 24/30
# 7414/7414 [==============================] - 134s 18ms/step - loss: 0.4291
# roc-auc: 0.7239 - roc-auc_val: 0.6462
# Epoch 25/30
# 7414/7414 [==============================] - 134s 18ms/step - loss: 0.4288
# roc-auc: 0.7262 - roc-auc_val: 0.646
# Epoch 26/30
# 7414/7414 [==============================] - 134s 18ms/step - loss: 0.4285
# roc-auc: 0.7262 - roc-auc_val: 0.6468
# Epoch 27/30
# 7414/7414 [==============================] - 73s 10ms/step - loss: 0.4282
# roc-auc: 0.7269 - roc-auc_val: 0.6457
# Epoch 28/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4278
# roc-auc: 0.7281 - roc-auc_val: 0.6466
# Epoch 29/30
# 7414/7414 [==============================] - 72s 10ms/step - loss: 0.4276
# roc-auc: 0.7287 - roc-auc_val: 0.647
# Epoch 30/30
# 7414/7414 [==============================] - 74s 10ms/step - loss: 0.4273
# roc-auc: 0.7293 - roc-auc_val: 0.6461
# ----------------------------------------------------------------------------------------------------
# Fold 4
# Epoch 1/30
# 7414/7414 [==============================] - 75s 10ms/step - loss: 0.4649
# roc-auc: 0.618 - roc-auc_val: 0.6009
# Epoch 2/30
# 7414/7414 [==============================] - 74s 10ms/step - loss: 0.4548
# roc-auc: 0.6482 - roc-auc_val: 0.6201
# Epoch 3/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4493
# roc-auc: 0.6657 - roc-auc_val: 0.6293
# Epoch 4/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4460
# roc-auc: 0.6772 - roc-auc_val: 0.6337
# Epoch 5/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4435
# roc-auc: 0.6862 - roc-auc_val: 0.6363
# Epoch 6/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4416
# roc-auc: 0.6919 - roc-auc_val: 0.639
# Epoch 7/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4401
# roc-auc: 0.6959 - roc-auc_val: 0.6403
# Epoch 8/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4388
# roc-auc: 0.7 - roc-auc_val: 0.6416
# Epoch 9/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4377
# roc-auc: 0.7044 - roc-auc_val: 0.6419
# Epoch 10/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4367
# roc-auc: 0.7059 - roc-auc_val: 0.643
# Epoch 11/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4359
# roc-auc: 0.7092 - roc-auc_val: 0.6436
# Epoch 12/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4351
# roc-auc: 0.7115 - roc-auc_val: 0.6444
# Epoch 13/30
# 7414/7414 [==============================] - 69s 9ms/step - loss: 0.4345
# roc-auc: 0.7118 - roc-auc_val: 0.6447
# Epoch 14/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4338
# roc-auc: 0.7141 - roc-auc_val: 0.6453
# Epoch 15/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4332
# roc-auc: 0.7167 - roc-auc_val: 0.645
# Epoch 16/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4326
# roc-auc: 0.7171 - roc-auc_val: 0.645
# Epoch 17/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4321
# roc-auc: 0.7181 - roc-auc_val: 0.6449
# Epoch 18/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4317
# roc-auc: 0.7186 - roc-auc_val: 0.6458
# Epoch 19/30
# 7414/7414 [==============================] - 70s 10ms/step - loss: 0.4313
# roc-auc: 0.7199 - roc-auc_val: 0.6455
# Epoch 20/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4309
# roc-auc: 0.7222 - roc-auc_val: 0.6457
# Epoch 21/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4305
# roc-auc: 0.7228 - roc-auc_val: 0.6459
# Epoch 22/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4301
# roc-auc: 0.723 - roc-auc_val: 0.6448
# Epoch 23/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4297
# roc-auc: 0.7232 - roc-auc_val: 0.6468
# Epoch 24/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4294
# roc-auc: 0.7251 - roc-auc_val: 0.6466
# Epoch 25/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4290
# roc-auc: 0.7261 - roc-auc_val: 0.647
# Epoch 26/30
# 7414/7414 [==============================] - 71s 10ms/step - loss: 0.4287
# roc-auc: 0.7273 - roc-auc_val: 0.6464
# Epoch 27/30
# 7414/7414 [==============================] - 72s 10ms/step - loss: 0.4285
# roc-auc: 0.7276 - roc-auc_val: 0.6466
# Epoch 28/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4281
# roc-auc: 0.727 - roc-auc_val: 0.647
# Epoch 29/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4278
# roc-auc: 0.7267 - roc-auc_val: 0.6466
# Epoch 30/30
# 7414/7414 [==============================] - 70s 9ms/step - loss: 0.4277
# roc-auc: 0.73 - roc-auc_val: 0.6469

# %%
# 0.4608

# %%
test_generator = DataSequence(test_x, np.zeros(test_x.shape[0]), batch_size=BATCH_SIZE * 4)

test_pred = np.zeros((test_x.shape[0], 1))
train_pred = np.zeros((train_x.shape[0], 1))

for i, (tr_idx, va_idx) in enumerate(kfold.split(train_x, train_y)):
    print('-'*100)
    print('Fold %d' % i)
    trn_x, trn_y = train_x[tr_idx], train_y[tr_idx]
    val_x, val_y = train_x[va_idx], train_y[va_idx]
    
    K.clear_session()
    model = Net(in_dim=train_x.shape[1], hiddens=(256,256,256))
    model.compile(loss='binary_crossentropy', optimizer='adam',)
    
    trn_generator = DataSequence(trn_x, trn_y, batch_size=BATCH_SIZE * 4)
    val_generator = DataSequence(val_x, val_y, batch_size=BATCH_SIZE * 4)
    
    model.load_weights(os.path.join(WEIGHT_PATH, 'user_topic_dnn_enc_B_weight_fold%d.h5' % i))
    
    train_pred[va_idx] = model.predict_generator(val_generator)
    test_pred += model.predict_generator(test_generator) / 5
    
    del trn_x, trn_y, val_x, val_y
    gc.collect()
    print('Predict Done.')
# Out:
# ----------------------------------------------------------------------------------------------------
# Fold 0
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 1
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 2
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 3
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 4
# Predict Done.

# %%
arr = np.vstack([train_pred, test_pred])
feat = pd.DataFrame(arr, columns=['user_topic_dnn_enc_B'])
feat.head()
# Out:
#    user_topic_dnn_enc_B
# 0              0.118857
# 1              0.118567
# 2              0.170073
# 3              0.057185
# 4              0.144254

# %%
feat.to_pickle('./feats/user_topic_dnn_enc_B.pkl')
