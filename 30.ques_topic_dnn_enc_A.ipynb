# %%
import pandas as pd
import numpy as np
import pickle
import gc
import os
import time
import copy
import multiprocessing as mp
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import StratifiedKFold
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_auc_score, log_loss
from tqdm import tqdm
from scipy import sparse, spatial
import warnings
warnings.filterwarnings('ignore')
tqdm.pandas()
# Out:
# /root/anaconda3/lib/python3.7/site-packages/sklearn/feature_extraction/text.py:17: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated, and in 3.8 it will stop working
#   from collections import Mapping, defaultdict

# %%
import os
import tensorflow as tf

os.environ['CUDA_VISIBLE_DEVICES'] = "0"
config = tf.compat.v1.ConfigProto()
config.gpu_options.allow_growth = True
session = tf.compat.v1.Session(config=config)

from keras.models import Sequential, Model
from keras.layers import Input, Dense, CuDNNLSTM, Bidirectional, Embedding, CuDNNGRU, Conv1D, MaxPooling1D
from keras.layers import Flatten, PReLU, Dropout, BatchNormalization, SpatialDropout1D, concatenate
from keras import initializers, regularizers, constraints, optimizers, layers
from keras.preprocessing.sequence import pad_sequences
from keras.utils import Sequence
from keras.callbacks import Callback
from keras import backend as K
from keras.engine.topology import Layer 
# from keras.utils.training_utils import multi_gpu_model
# Out:
# Using TensorFlow backend.

# %%
tic = time.time()
DATA_PATH = '../pkl/'
SAVE_PATH = './feats/'
WEIGHT_PATH = './weights/'
if not os.path.exists(SAVE_PATH):
    print('create dir: %s' % SAVE_PATH)
    os.mkdir(SAVE_PATH)
if not os.path.exists(WEIGHT_PATH):
    print('create dir: %s' % WEIGHT_PATH)
    os.mkdir(WEIGHT_PATH)

print('ques_topic_dnn_enc...')
# Out:
# ques_topic_dnn_enc...

# %%
data = pd.read_pickle(os.path.join(DATA_PATH, 'invite_data.pkl'))
question_info = pd.read_pickle(os.path.join(DATA_PATH, 'question_info.pkl'))
topic = pd.read_pickle(os.path.join(DATA_PATH, 'topic.pkl'))
len_train = (~data['label'].isnull()).sum()
print(len_train)
# Out:
# 9489162

# %%
data.head()
# Out:
#    iday  ihour  itime  label         qid         uid
# 0  3865     22  92782    0.0  2166419046   401693808
# 1  3844     11  92267    0.0  1550017551  3392373099
# 2  3862     15  92703    0.0   604029601  2317670257
# 3  3849     11  92387    0.0  2350061229  1618461867
# 4  3867      4  92812    0.0  2443223942  3544409350

# %%
question_info.head()
# Out:
#           qid  qtime                                           title_sw  \
# 0  2234111670  24437  [211, 204, 1715, 69, 2033, 138, 57, 138, 8, 28...
# 1   760329790  41900  [69, 2033, 138, 2616, 2668, 36, 2594, 1165, 20...
# 2   741313548  48789  [153, 662, 1218, 853, 325, 1056, 467, 398, 102...
# 3  3481466230  52455  [22, 179, 57, 451, 594, 118, 882, 655, 1, 433,...
# 4  3966197028  54473  [1622, 223, 1218, 853, 390, 220, 753, 909, 557...
#
#                                title_w  \
# 0                  [22414, 963, 10458]
# 1  [12677, 16829, 15201, 6419, 101839]
# 2             [700, 2781, 3280, 81215]
# 3    [3312, 1823, 1505, 638, 166, 461]
# 4                     [700, 895, 2253]
#
#                                              desc_sw  \
# 0                                                [0]
# 1  [146, 982, 401, 297, 17, 2616, 2668, 36, 2594,...
# 2  [1956, 3583, 153, 34, 35, 1016, 586, 586, 716,...
# 3  [323, 37, 1, 606, 1227, 29, 22, 179, 7, 44, 27...
# 4                                                [0]
#
#                                               desc_w  \
# 0                                                [0]
# 1  [1296, 2118, 12677, 16829, 15201, 6419, 101839...
# 2  [732, 24400, 48321, 39608, 20788, 219486, 1183...
# 3  [6642, 4214, 3312, 1505, 2205, 232, 294, 7177,...
# 4                                                [0]
#
#                            topic  qday  qhour
# 0         [321, 730, 5784, 4389]  1018      5
# 1             [278, 12673, 4677]  1745     20
# 2                          [226]  2032     21
# 3                     [51, 4468]  2185     15
# 4  [54700, 81, 57, 17670, 43574]  2269     17

# %%
data = data.merge(question_info[['qid', 'topic']], 'left', 'qid')
# data['topic'] = data['topic'].fillna('-1')
data.head()
# Out:
#    iday  ihour  itime  label         qid         uid                   topic
# 0  3865     22  92782    0.0  2166419046   401693808  [456, 112, 9566, 5310]
# 1  3844     11  92267    0.0  1550017551  3392373099               [2, 3095]
# 2  3862     15  92703    0.0   604029601  2317670257   [6090, 2156, 97, 456]
# 3  3849     11  92387    0.0  2350061229  1618461867                   [856]
# 4  3867      4  92812    0.0  2443223942  3544409350            [26, 76, 17]

# %%
max_len = data['topic'].apply(len).max()
print(max_len)
# Out:
# 13

# %%
np.random.seed(42)
def shuffle(l):
    np.random.shuffle(l)
    return l

data['topic'] = data['topic'].progress_apply(shuffle)
# Out:
# 100%|██████████| 10630845/10630845 [00:40<00:00, 263008.85it/s]

# %%
data.head()
# Out:
#    iday  ihour  itime  label         qid         uid                   topic
# 0  3865     22  92782    0.0  2166419046   401693808  [112, 5310, 456, 9566]
# 1  3844     11  92267    0.0  1550017551  3392373099               [3095, 2]
# 2  3862     15  92703    0.0   604029601  2317670257   [2156, 97, 6090, 456]
# 3  3849     11  92387    0.0  2350061229  1618461867                   [856]
# 4  3867      4  92812    0.0  2443223942  3544409350            [26, 76, 17]

# %%
qid_topic_map_30 = data[['qid', 'topic']].copy()
qid_topic_map_30.drop_duplicates(subset=['qid'], inplace=True)
qid_topic_map_30.to_pickle('./shuffle_map/qid_topic_map_30.pkl')
print(qid_topic_map_30.shape)
# Out:
# (1083727, 2)

# %%
topics = pad_sequences(data['topic'], maxlen=max_len)

# %%
topics
# Out:
# array([[    0,     0,     0, ...,  9566,  5310,   456],
#        [    0,     0,     0, ...,     0,     2,  3095],
#        [    0,     0,     0, ...,  2156,    97,  6090],
#        ...,
#        [    0,     0,     0, ...,     0,     0,  9570],
#        [    0,     0,     0, ...,     0, 11184,  8444],
#        [    0,     0,     0, ...,     0,  5196,  4597]], dtype=int32)

# %%
topics.shape
# Out:
# (10630845, 13)

# %%
embed_weights = np.array([[0] * 64] + [list(v) for v in topic['vector'].values])

# %%
embed_weights.shape
# Out:
# (100001, 64)

# %%
class DataSequence(Sequence):
    
    def __init__(self, x, y, batch_size=128):
        self.x = x
        self.y = y
        self.batch_size = batch_size
         
    def __len__(self):
        return int(np.ceil(self.x.shape[0] / float(self.batch_size)))
    
    def __getitem__(self, idx):
        batch_idx = np.arange(idx * self.batch_size, min((idx + 1) * self.batch_size, self.x.shape[0]))
        batch_x = self.x[batch_idx]# .toarray() # sparse to dense
        batch_y = self.y[batch_idx]
        return batch_x, batch_y

# %%
class MetricsCallback(Callback):
    def __init__(self, x_trn, y_trn, x_val, y_val, batch_size=128, save_name='weight.h5'):
        self.trn_generator = DataSequence(x_trn, y_trn, BATCH_SIZE)
        self.val_generator = DataSequence(x_val, y_val, BATCH_SIZE)
        self.y_trn = y_trn
        self.y_val = y_val
        self.save_name = save_name
        self.best_score = 0.5

    def on_epoch_end(self, epoch, logs={}):
        # eval train
        y_pred = self.model.predict_generator(self.trn_generator, 
                                              max_queue_size=10, 
                                              workers=1, 
                                              use_multiprocessing=False, 
                                              verbose=0)
        roc = roc_auc_score(self.y_trn, y_pred)
        # eval valid
        y_pred_val = self.model.predict_generator(self.val_generator, 
                                              max_queue_size=10, 
                                              workers=1, 
                                              use_multiprocessing=False, 
                                              verbose=0)
        roc_val = roc_auc_score(self.y_val, y_pred_val)
        print('\rroc-auc: %s - roc-auc_val: %s' % (str(round(roc,4)),str(round(roc_val,4))),end=100*' '+'\n')
#         print(roc_val)
#         print(log_loss(self.y_val, y_pred_val)/len(y_pred_val))
        if roc_val > self.best_score:
            self.best_score = roc_val
            self.model.save_weights(os.path.join(WEIGHT_PATH, self.save_name))
        
        return

# %%
def Net(in_dim, hiddens=(256,)):
    inp = Input(shape=(max_len,))
    x = Embedding(embed_weights.shape[0], embed_weights.shape[1], weights=[embed_weights], trainable=False)(inp)
    x = Dropout(0.2)(x)
    x = Conv1D(256, 2, padding='valid', activation='relu', strides=1)(x)
    x = MaxPooling1D(pool_size=4)(x)
    x = Flatten()(x)
    for hs in hiddens:
        x = Dense(hs)(x)
        x = BatchNormalization()(x)
        x = PReLU()(x)
        x = Dropout(0.2)(x)
    out = Dense(1, activation="sigmoid")(x)
    model = Model(inputs=inp, outputs=out)
    return model

# %%
train_x = topics[:len_train]
test_x = topics[len_train:]
train_y = data['label'].values[:len_train]

# %%
print(train_x.shape)
print(test_x.shape)
print(train_y.sum() / len(train_y))
# Out:
# (9489162, 13)
# (1141683, 13)
# 0.1773515933229931

# %%
BATCH_SIZE = 1024

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for i, (tr_idx, va_idx) in enumerate(kfold.split(train_x, train_y)):
    print('-'*100)
    print('Fold %d' % i)
    trn_x, trn_y = train_x[tr_idx], train_y[tr_idx]
    val_x, val_y = train_x[va_idx], train_y[va_idx]
    
    K.clear_session()
    model = Net(in_dim=train_x.shape[1], hiddens=(256,256,256))
    model.compile(loss='binary_crossentropy', optimizer='adam',)
    
    trn_generator = DataSequence(trn_x, trn_y, batch_size=BATCH_SIZE)
    val_generator = DataSequence(val_x, val_y, batch_size=BATCH_SIZE)
    
    history = model.fit_generator(generator=trn_generator, 
                        epochs=30, 
                        verbose=1, 
                        callbacks=[MetricsCallback(trn_x, trn_y, val_x, val_y, 
                                                   batch_size=BATCH_SIZE*4, 
                                                   save_name='ques_topic_dnn_enc_A_weight_fold%d.h5' % i)], 
                        max_queue_size=100, 
                        workers=1, 
                        use_multiprocessing=False,)
    
    del trn_x, trn_y, val_x, val_y
    gc.collect()
# Out:
# ----------------------------------------------------------------------------------------------------
# Fold 0
# Epoch 1/30
# 7414/7414 [==============================] - 183s 25ms/step - loss: 0.4604
# roc-auc: 0.6126 - roc-auc_val: 0.6112
# Epoch 2/30
# 7414/7414 [==============================] - 164s 22ms/step - loss: 0.4566
# roc-auc: 0.6205 - roc-auc_val: 0.6178
# Epoch 3/30
# 7414/7414 [==============================] - 158s 21ms/step - loss: 0.4553
# roc-auc: 0.6254 - roc-auc_val: 0.622
# Epoch 4/30
# 7414/7414 [==============================] - 155s 21ms/step - loss: 0.4545
# roc-auc: 0.6279 - roc-auc_val: 0.6242
# Epoch 5/30
# 7414/7414 [==============================] - 152s 21ms/step - loss: 0.4540
# roc-auc: 0.6289 - roc-auc_val: 0.6249
# Epoch 6/30
# 7414/7414 [==============================] - 117s 16ms/step - loss: 0.4535
# roc-auc: 0.6327 - roc-auc_val: 0.6279
# Epoch 7/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4531
# roc-auc: 0.6342 - roc-auc_val: 0.6287
# Epoch 8/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4528
# roc-auc: 0.6367 - roc-auc_val: 0.6302
# Epoch 9/30
# 7414/7414 [==============================] - 111s 15ms/step - loss: 0.4525
# roc-auc: 0.6374 - roc-auc_val: 0.631
# Epoch 10/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4523
# roc-auc: 0.6387 - roc-auc_val: 0.6317
# Epoch 11/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4520
# roc-auc: 0.6395 - roc-auc_val: 0.6324
# Epoch 12/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4518
# roc-auc: 0.641 - roc-auc_val: 0.6333
# Epoch 13/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4516
# roc-auc: 0.6421 - roc-auc_val: 0.634
# Epoch 14/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4515
# roc-auc: 0.6419 - roc-auc_val: 0.6338
# Epoch 15/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4513
# roc-auc: 0.6427 - roc-auc_val: 0.6343
# Epoch 16/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4512
# roc-auc: 0.6439 - roc-auc_val: 0.6351
# Epoch 17/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4510
# roc-auc: 0.6449 - roc-auc_val: 0.6356
# Epoch 18/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4509
# roc-auc: 0.6458 - roc-auc_val: 0.6363
# Epoch 19/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4508
# roc-auc: 0.6457 - roc-auc_val: 0.6363
# Epoch 20/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4507
# roc-auc: 0.647 - roc-auc_val: 0.6372
# Epoch 21/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4506
# roc-auc: 0.646 - roc-auc_val: 0.6365
# Epoch 22/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4506
# roc-auc: 0.648 - roc-auc_val: 0.6376
# Epoch 23/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4504
# roc-auc: 0.6484 - roc-auc_val: 0.638
# Epoch 24/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4504
# roc-auc: 0.6488 - roc-auc_val: 0.6379
# Epoch 25/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4502
# roc-auc: 0.6498 - roc-auc_val: 0.6385
# Epoch 26/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4502
# roc-auc: 0.6499 - roc-auc_val: 0.6386
# Epoch 27/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4501
# roc-auc: 0.6503 - roc-auc_val: 0.639
# Epoch 28/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4501
# roc-auc: 0.6512 - roc-auc_val: 0.6393
# Epoch 29/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4500
# roc-auc: 0.65 - roc-auc_val: 0.6386
# Epoch 30/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4499
# roc-auc: 0.6519 - roc-auc_val: 0.6395
# ----------------------------------------------------------------------------------------------------
# Fold 1
# Epoch 1/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4606
# roc-auc: 0.6131 - roc-auc_val: 0.6116
# Epoch 2/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4566
# roc-auc: 0.6198 - roc-auc_val: 0.6176
# Epoch 3/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4553
# roc-auc: 0.6247 - roc-auc_val: 0.622
# Epoch 4/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4545
# roc-auc: 0.6283 - roc-auc_val: 0.6245
# Epoch 5/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4539
# roc-auc: 0.6306 - roc-auc_val: 0.6258
# Epoch 6/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4535
# roc-auc: 0.633 - roc-auc_val: 0.6279
# Epoch 7/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4531
# roc-auc: 0.635 - roc-auc_val: 0.6292
# Epoch 8/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4527
# roc-auc: 0.6359 - roc-auc_val: 0.6299
# Epoch 9/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4525
# roc-auc: 0.6372 - roc-auc_val: 0.6309
# Epoch 10/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4522
# roc-auc: 0.6386 - roc-auc_val: 0.6315
# Epoch 11/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4520
# roc-auc: 0.6395 - roc-auc_val: 0.632
# Epoch 12/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4518
# roc-auc: 0.64 - roc-auc_val: 0.6325
# Epoch 13/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4517
# roc-auc: 0.6415 - roc-auc_val: 0.6335
# Epoch 14/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4515
# roc-auc: 0.643 - roc-auc_val: 0.6344
# Epoch 15/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4514
# roc-auc: 0.6434 - roc-auc_val: 0.6348
# Epoch 16/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4512
# roc-auc: 0.6447 - roc-auc_val: 0.6355
# Epoch 17/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4511
# roc-auc: 0.6447 - roc-auc_val: 0.6355
# Epoch 18/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4510
# roc-auc: 0.6453 - roc-auc_val: 0.6358
# Epoch 19/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4508
# roc-auc: 0.6468 - roc-auc_val: 0.6366
# Epoch 20/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4507
# roc-auc: 0.6467 - roc-auc_val: 0.6365
# Epoch 21/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4506
# roc-auc: 0.6467 - roc-auc_val: 0.6368
# Epoch 22/30
# 7414/7414 [==============================] - 103s 14ms/step - loss: 0.4506
# roc-auc: 0.6483 - roc-auc_val: 0.6376
# Epoch 23/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4504
# roc-auc: 0.6479 - roc-auc_val: 0.6373
# Epoch 24/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4504
# roc-auc: 0.6489 - roc-auc_val: 0.6378
# Epoch 25/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4502
# roc-auc: 0.6496 - roc-auc_val: 0.6385
# Epoch 26/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4502
# roc-auc: 0.6503 - roc-auc_val: 0.6387
# Epoch 27/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4500
# roc-auc: 0.6503 - roc-auc_val: 0.6387
# Epoch 28/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4500
# roc-auc: 0.6507 - roc-auc_val: 0.6391
# Epoch 29/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4499
# roc-auc: 0.651 - roc-auc_val: 0.6391
# Epoch 30/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4499
# roc-auc: 0.6519 - roc-auc_val: 0.6396
# ----------------------------------------------------------------------------------------------------
# Fold 2
# Epoch 1/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4610
# roc-auc: 0.6099 - roc-auc_val: 0.6078
# Epoch 2/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4567
# roc-auc: 0.6201 - roc-auc_val: 0.6175
# Epoch 3/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4554
# roc-auc: 0.6244 - roc-auc_val: 0.6209
# Epoch 4/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4545
# roc-auc: 0.6282 - roc-auc_val: 0.6239
# Epoch 5/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4539
# roc-auc: 0.6311 - roc-auc_val: 0.6262
# Epoch 6/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4535
# roc-auc: 0.6324 - roc-auc_val: 0.6267
# Epoch 7/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4531
# roc-auc: 0.6343 - roc-auc_val: 0.6283
# Epoch 8/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4528
# roc-auc: 0.6362 - roc-auc_val: 0.6296
# Epoch 9/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4525
# roc-auc: 0.6367 - roc-auc_val: 0.6299
# Epoch 10/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4523
# roc-auc: 0.6384 - roc-auc_val: 0.6311
# Epoch 11/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4521
# roc-auc: 0.6396 - roc-auc_val: 0.6321
# Epoch 12/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4519
# roc-auc: 0.6407 - roc-auc_val: 0.6329
# Epoch 13/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4517
# roc-auc: 0.6411 - roc-auc_val: 0.633
# Epoch 14/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4515
# roc-auc: 0.6424 - roc-auc_val: 0.634
# Epoch 15/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4514
# roc-auc: 0.6425 - roc-auc_val: 0.6336
# Epoch 16/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4512
# roc-auc: 0.6438 - roc-auc_val: 0.6348
# Epoch 17/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4511
# roc-auc: 0.6443 - roc-auc_val: 0.6351
# Epoch 18/30
# 7414/7414 [==============================] - 111s 15ms/step - loss: 0.4510
# roc-auc: 0.6457 - roc-auc_val: 0.6361
# Epoch 19/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4509
# roc-auc: 0.645 - roc-auc_val: 0.6353
# Epoch 20/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4507
# roc-auc: 0.6464 - roc-auc_val: 0.6366
# Epoch 21/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4506
# roc-auc: 0.6469 - roc-auc_val: 0.6369
# Epoch 22/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4505
# roc-auc: 0.647 - roc-auc_val: 0.6367
# Epoch 23/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4504
# roc-auc: 0.6477 - roc-auc_val: 0.6371
# Epoch 24/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4504
# roc-auc: 0.6484 - roc-auc_val: 0.6375
# Epoch 25/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4503
# roc-auc: 0.6493 - roc-auc_val: 0.6382
# Epoch 26/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4501
# roc-auc: 0.6492 - roc-auc_val: 0.6382
# Epoch 27/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4501
# roc-auc: 0.6496 - roc-auc_val: 0.6381
# Epoch 28/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4500
# roc-auc: 0.6498 - roc-auc_val: 0.6385
# Epoch 29/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4499
# roc-auc: 0.6511 - roc-auc_val: 0.6394
# Epoch 30/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4499
# roc-auc: 0.6511 - roc-auc_val: 0.639
# ----------------------------------------------------------------------------------------------------
# Fold 3
# Epoch 1/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4609
# roc-auc: 0.6123 - roc-auc_val: 0.6104
# Epoch 2/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4567
# roc-auc: 0.6203 - roc-auc_val: 0.617
# Epoch 3/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4553
# roc-auc: 0.6257 - roc-auc_val: 0.6213
# Epoch 4/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4545
# roc-auc: 0.6291 - roc-auc_val: 0.6239
# Epoch 5/30
# 7414/7414 [==============================] - 103s 14ms/step - loss: 0.4539
# roc-auc: 0.6301 - roc-auc_val: 0.6245
# Epoch 6/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4534
# roc-auc: 0.6331 - roc-auc_val: 0.6263
# Epoch 7/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4531
# roc-auc: 0.6347 - roc-auc_val: 0.6275
# Epoch 8/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4528
# roc-auc: 0.6361 - roc-auc_val: 0.6284
# Epoch 9/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4525
# roc-auc: 0.637 - roc-auc_val: 0.6291
# Epoch 10/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4523
# roc-auc: 0.6385 - roc-auc_val: 0.6299
# Epoch 11/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4520
# roc-auc: 0.6396 - roc-auc_val: 0.6308
# Epoch 12/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4518
# roc-auc: 0.6404 - roc-auc_val: 0.6314
# Epoch 13/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4516
# roc-auc: 0.6418 - roc-auc_val: 0.6324
# Epoch 14/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4515
# roc-auc: 0.6422 - roc-auc_val: 0.6325
# Epoch 15/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4513
# roc-auc: 0.6428 - roc-auc_val: 0.6329
# Epoch 16/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4512
# roc-auc: 0.6441 - roc-auc_val: 0.6337
# Epoch 17/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4510
# roc-auc: 0.6449 - roc-auc_val: 0.6343
# Epoch 18/30
# 7414/7414 [==============================] - 107s 14ms/step - loss: 0.4509
# roc-auc: 0.6454 - roc-auc_val: 0.6347
# Epoch 19/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4508
# roc-auc: 0.6467 - roc-auc_val: 0.6357
# Epoch 20/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4507
# roc-auc: 0.6465 - roc-auc_val: 0.6354
# Epoch 21/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4506
# roc-auc: 0.6475 - roc-auc_val: 0.6361
# Epoch 22/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4505
# roc-auc: 0.6478 - roc-auc_val: 0.6363
# Epoch 23/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4504
# roc-auc: 0.6484 - roc-auc_val: 0.6364
# Epoch 24/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4502
# roc-auc: 0.6494 - roc-auc_val: 0.637
# Epoch 25/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4502
# roc-auc: 0.6498 - roc-auc_val: 0.6373
# Epoch 26/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4501
# roc-auc: 0.6502 - roc-auc_val: 0.6378
# Epoch 27/30
# 7414/7414 [==============================] - 103s 14ms/step - loss: 0.4501
# roc-auc: 0.6505 - roc-auc_val: 0.6376
# Epoch 28/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4500
# roc-auc: 0.6509 - roc-auc_val: 0.638
# Epoch 29/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4499
# roc-auc: 0.6506 - roc-auc_val: 0.638
# Epoch 30/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4499
# roc-auc: 0.6509 - roc-auc_val: 0.6382
# ----------------------------------------------------------------------------------------------------
# Fold 4
# Epoch 1/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4612
# roc-auc: 0.6111 - roc-auc_val: 0.609
# Epoch 2/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4566
# roc-auc: 0.6201 - roc-auc_val: 0.6168
# Epoch 3/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4553
# roc-auc: 0.6251 - roc-auc_val: 0.6213
# Epoch 4/30
# 7414/7414 [==============================] - 103s 14ms/step - loss: 0.4545
# roc-auc: 0.6289 - roc-auc_val: 0.6241
# Epoch 5/30
# 7414/7414 [==============================] - 103s 14ms/step - loss: 0.4539
# roc-auc: 0.6308 - roc-auc_val: 0.6254
# Epoch 6/30
# 7414/7414 [==============================] - 105s 14ms/step - loss: 0.4534
# roc-auc: 0.6333 - roc-auc_val: 0.6272
# Epoch 7/30
# 7414/7414 [==============================] - 104s 14ms/step - loss: 0.4531
# roc-auc: 0.6344 - roc-auc_val: 0.628
# Epoch 8/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4527
# roc-auc: 0.6365 - roc-auc_val: 0.6295
# Epoch 9/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4524
# roc-auc: 0.6371 - roc-auc_val: 0.6295
# Epoch 10/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4522
# roc-auc: 0.6383 - roc-auc_val: 0.6305
# Epoch 11/30
# 7414/7414 [==============================] - 111s 15ms/step - loss: 0.4520
# roc-auc: 0.6402 - roc-auc_val: 0.6318
# Epoch 12/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4518
# roc-auc: 0.6405 - roc-auc_val: 0.6318
# Epoch 13/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4516
# roc-auc: 0.642 - roc-auc_val: 0.6329
# Epoch 14/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4515
# roc-auc: 0.6426 - roc-auc_val: 0.6333
# Epoch 15/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4513
# roc-auc: 0.643 - roc-auc_val: 0.6337
# Epoch 16/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4512
# roc-auc: 0.6437 - roc-auc_val: 0.6339
# Epoch 17/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4510
# roc-auc: 0.6444 - roc-auc_val: 0.6344
# Epoch 18/30
# 7414/7414 [==============================] - 106s 14ms/step - loss: 0.4509
# roc-auc: 0.6452 - roc-auc_val: 0.635
# Epoch 19/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4508
# roc-auc: 0.6455 - roc-auc_val: 0.6347
# Epoch 20/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4507
# roc-auc: 0.6467 - roc-auc_val: 0.6357
# Epoch 21/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4506
# roc-auc: 0.6471 - roc-auc_val: 0.636
# Epoch 22/30
# 7414/7414 [==============================] - 109s 15ms/step - loss: 0.4505
# roc-auc: 0.6482 - roc-auc_val: 0.6367
# Epoch 23/30
# 7414/7414 [==============================] - 108s 15ms/step - loss: 0.4504
# roc-auc: 0.6478 - roc-auc_val: 0.6364
# Epoch 24/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4503
# roc-auc: 0.6489 - roc-auc_val: 0.6372
# Epoch 25/30
# 7414/7414 [==============================] - 110s 15ms/step - loss: 0.4502
# roc-auc: 0.6493 - roc-auc_val: 0.6376
# Epoch 26/30
# 7414/7414 [==============================] - 125s 17ms/step - loss: 0.4501
# roc-auc: 0.6498 - roc-auc_val: 0.6377
# Epoch 27/30
# 7414/7414 [==============================] - 137s 18ms/step - loss: 0.4500
# roc-auc: 0.65 - roc-auc_val: 0.6376
# Epoch 28/30
# 7414/7414 [==============================] - 116s 16ms/step - loss: 0.4500
# roc-auc: 0.6513 - roc-auc_val: 0.6383
# Epoch 29/30
# 7414/7414 [==============================] - 118s 16ms/step - loss: 0.4499
# roc-auc: 0.6516 - roc-auc_val: 0.6387
# Epoch 30/30
# 7414/7414 [==============================] - 117s 16ms/step - loss: 0.4498
# roc-auc: 0.6515 - roc-auc_val: 0.6386

# %%
# 0.4608

# %%
BATCH_SIZE = 1024

kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

test_generator = DataSequence(test_x, np.zeros(test_x.shape[0]), batch_size=BATCH_SIZE * 4)

test_pred = np.zeros((test_x.shape[0], 1))
train_pred = np.zeros((train_x.shape[0], 1))

for i, (tr_idx, va_idx) in enumerate(kfold.split(train_x, train_y)):
    print('-'*100)
    print('Fold %d' % i)
    trn_x, trn_y = train_x[tr_idx], train_y[tr_idx]
    val_x, val_y = train_x[va_idx], train_y[va_idx]
    
    K.clear_session()
    model = Net(in_dim=train_x.shape[1], hiddens=(256,256,256))
    model.compile(loss='binary_crossentropy', optimizer='adam',)
    
    trn_generator = DataSequence(trn_x, trn_y, batch_size=BATCH_SIZE * 4)
    val_generator = DataSequence(val_x, val_y, batch_size=BATCH_SIZE * 4)
    
    model.load_weights(os.path.join(WEIGHT_PATH, 'ques_topic_dnn_enc_A_weight_fold%d.h5' % i))
    
    train_pred[va_idx] = model.predict_generator(val_generator)
    test_pred += model.predict_generator(test_generator) / 5
    
    print(roc_auc_score(val_y, train_pred[va_idx]))
    
    del trn_x, trn_y, val_x, val_y
    gc.collect()
    print('Predict Done.')
# Out:
# ----------------------------------------------------------------------------------------------------
# Fold 0
# WARNING:tensorflow:From /root/anaconda3/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# 0.6395178373582746
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 1
# 0.6396183939223585
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 2
# 0.639372822166486
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 3
# 0.6381767472531317
# Predict Done.
# ----------------------------------------------------------------------------------------------------
# Fold 4
# 0.6386717729079339
# Predict Done.

# %%
arr = np.vstack([train_pred, test_pred])
feat = pd.DataFrame(arr, columns=['ques_topic_dnn_enc_A'])
feat.head()
# Out:
#    ques_topic_dnn_enc_A
# 0              0.135464
# 1              0.158589
# 2              0.063926
# 3              0.157325
# 4              0.248642

# %%
feat.to_pickle('./feats/ques_topic_dnn_enc_A.pkl')
